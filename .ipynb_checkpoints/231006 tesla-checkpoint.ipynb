# %%
import numpy as np
import pandas as pd
import configparser
import psycopg2
import os
import ast
from sklearn.preprocessing import MinMaxScaler
import networkx as nx
import random
import time
import math
import datetime
import csv
import statistics
from collections import defaultdict
from statistics import harmonic_mean

start = time.time()

def calculate_mean(numbers):
    return sum(numbers) / len(numbers)

def calculate_standard_deviation(numbers):
    return statistics.stdev(numbers)

def combine_lists(full_list):
    combined = defaultdict(list)
    
    # 모든 리스트에 대한 처리
    for sublist in full_list:
        for item in sublist:
            entrez_id, rwr_score = item
            combined[entrez_id].append(rwr_score)
    
    # 조화평균 및 결과 리스트 만들기
    result = []
    for entrez_id, scores in combined.items():
        if len(scores) == 1:
            result.append([entrez_id, scores[0]])  # 값이 하나면 그대로 추가
        else:
            # 조화평균 계산
            harmonic_mean_score = harmonic_mean(scores)
            result.append([entrez_id, harmonic_mean_score])
    
    return result

def compound_target(compoundid):

    conn_cur.execute(f"with tmp1 as (select cg.geneid from compound_gene cg where (cg.compid = '{compoundid}' and cg.relationsign in ('activate','inhibit')))" 
                    f"select g.entrezid from gene g,tmp1 where g.geneid=tmp1.geneid;")
    compound_gene1=conn_cur.fetchall()

    compound_gene=set(compound_gene1)
    compound_gene=list(compound_gene)
    
    # Compound-target gene List 생성
    target_gene_list = [] 
    for i in range(len(compound_gene)):
        interaction_gene = compound_gene[i][0]
        if interaction_gene in entrez_list:
            target_gene_list.append(interaction_gene)        
        else:
            continue

    # restart node에 적용할 target gene List 생성
    target_node = [] 
    for entrez in target_gene_list:
        node_ = node_index.get(entrez) 
        target_node.append(node_)

    conn_cur.execute(f"with tmp2 as (select cg.geneid from compound_gene cg where cg.compid = '{compoundid}' and relationsign='associate')" 
                    f"select g.entrezid from gene g,tmp2 where g.geneid=tmp2.geneid;")

    compound_gene2=conn_cur.fetchall()

    compound_gene=set(compound_gene2)
    compound_gene=list(compound_gene)

    indirected_target_gene_list = [] 
    for i in range(len(compound_gene)):
        interaction_gene = compound_gene[i][0]
        if interaction_gene in entrez_list:
            indirected_target_gene_list.append(interaction_gene)        
        else:
            continue      

    num1=len(target_gene_list) #target gene list 갯수
    directed_target_gene_list.append(num1)
    num2=len(indirected_target_gene_list) #indirected target gene list 갯수 
    indirected_target_gene_list_count.append(num2)
    
    print("Compound",compoundid,"Target gene 개수",num1)
    print("Compound",compoundid,"indirected_Target gene 개수",num2)
    
    #indirect nodes 정의
    indirect_nodes= []
    for entrez in indirected_target_gene_list:
        node_ = node_index.get(entrez) 
        indirect_nodes.append(node_)

    # PPI network RWR을 위한 initialize
    initialized = RWR_initializing(G, seed_nodes=target_node,indirect_target_nodes=indirect_nodes, is_weighted=False) 

    # RWR 실행
    rwr = RWR(initialized=initialized, prob=0.2, max_iter=100, tol=1.0e-6)
    rwr_mapping_entrez = [[entrez_list[i], rwr[node_index.get(entrez_list[i])]] for i in range(len(entrez_list))]
    
    var_name1 = f'{compoundid}_num1'
    var_name2 = f'{compoundid}_num2'

    # 전역 변수 설정
    globals()[var_name1] = num1
    globals()[var_name2] = num2
    
    return rwr_mapping_entrez

def rwr_compound_target(count,entrez_list):
    
    num1=directed_target_gene_list[count]
    num2=indirected_target_gene_list_count[count]
    
    random_interaction_gene1 = random.sample(entrez_list, num1)
    remaining_entrez_list = [gene for gene in entrez_list if gene not in random_interaction_gene1]
    random_interaction_gene2 = random.sample(remaining_entrez_list, num2)
    
# restart node에 적용할 target gene List 생성
    target_node = [] 
    for entrez in random_interaction_gene1:
        node_ = node_index.get(entrez)
        target_node.append(node_)

    #indirect nodes 정의
    indirect_nodes= []
    for entrez in random_interaction_gene2:
        node_ = node_index.get(entrez)
        indirect_nodes.append(node_)

    # PPI network RWR을 위한 initialize
    initialized = RWR_initializing(G, seed_nodes=target_node,indirect_target_nodes=indirect_nodes, is_weighted=False) 
    
# RWR 실행
    rwr=RWR(initialized=initialized, prob=0.2, max_iter=100, tol=1.0e-6)
    rwr_mapping_entrez = [[entrez_list[i], rwr[node_index.get(entrez_list[i])]] for i in range(len(entrez_list))]
    return rwr_mapping_entrez

def create_ppi_network(network_data):
    network_data = network_data.astype({'Entrez Gene Interactor A': str,
                                        'Entrez Gene Interactor B': str})

    # symbol list를 생성하고 unique 값만 가지도록 생성
    symbolA = network_data.loc[:, 'Entrez Gene Interactor A'].to_list()
    symbolB = network_data.loc[:, 'Entrez Gene Interactor B'].to_list()

    symbol_list = symbolA + symbolB 
    symbol_list = set(symbol_list) 
    symbol_list = list(symbol_list)

    # 모든 symbol에 index를 딕셔너리에서 부여
    node_index = {}
    for i in range(len(symbol_list)):
        node_index[symbol_list[i]] = i

    # index로 node_list 생성
    node_list = node_index.values()

    # index로 edge_list 생성
    edge_list = network_data[['Entrez Gene Interactor A', 'Entrez Gene Interactor B']].values.tolist()  #
    for i in range(len(edge_list)):
        edge_list[i][0] = node_index.get(edge_list[i][0])
        edge_list[i][1] = node_index.get(edge_list[i][1])
    
    # 무방향 그래프 오브젝트 생성
    G = nx.Graph()

    # 그래프에 노드 추가
    G.add_nodes_from(node_list)

    # 그래프에 엣지 추가
    G.add_edges_from(edge_list)

    print(f'Number of created nodes: {G.number_of_nodes()}')
    print(f'Number of created edges: {G.number_of_edges()}')

    return G, node_index

def RWR_initializing(G, seed_nodes, indirect_target_nodes, is_weighted=False):
    norm_A = np.zeros(shape=(len(G), len(G)))
    if is_weighted:  
        for i, neighbor_dict in G.adjacency():
            for j, v in neighbor_dict.items():
                norm_A[i][j] = v.get("weight", 1 / len(neighbor_dict))
    else:  
        for i, neighbor_dict in G.adjacency():  
            for j, v in neighbor_dict.items():  
                norm_A[i][j] = 1 / len(neighbor_dict)
    
    # seed nodes와 indirect target nodes를 모두 포함한 딕셔너리 생성
    personalization = {node: 1 for node in seed_nodes}
    for node in indirect_target_nodes:
        personalization[node] = 0.3  
        
    r_0 = np.array([personalization.get(n, 0) for n in range(len(G))]) 
    r_c = np.repeat(1 / len(G), len(G)) 
    return {"norm_A": norm_A, "r_0": r_0, "r_c": r_c, "N": len(G)}

def RWR(initialized, prob=0.85, max_iter=100, tol=1.0e-6):
    if initialized is None:
        raise ValueError('initialized information must be required')

    norm_A = initialized['norm_A']  # 인접행렬 A (정규화된)
    r_0 = initialized['r_0']        # 시작 노드
    r_c = initialized['r_c']        # 가중치 행렬
    N = initialized['N']            # 노드의 개수
    for iteration in range(max_iter):
        r_prev = r_c
        r_c = prob * r_c @ norm_A + (1 - prob) * r_0  # RWR algorithm
        err = np.absolute(r_c - r_prev).sum()
        if err < N * tol:
            print(f'RWR iteration = {iteration + 1}')
            print('Converged')
            return r_c
        else:
            print(f'RWR iteration = {iteration + 1}, Iteration until convergence ...')
            print(f'{err} -> {N * tol}')
    return "NotConverged"

# postgresql DB 연동
config = configparser.ConfigParser()
config.read('db_config.ini')
conn=psycopg2.connect(host="168.131.30.66", dbname="coconut",user="dbuser",password="jnudl1") #데이터이름변경
conn_cur = conn.cursor()

# BIOGRID-Homo_sapiens Data 기반 PPI Network 구축
network_data = pd.read_csv("/data/home/sss2061/식약처/Data/BIOGRID-ORGANISM-Homo_sapiens.tab3.txt", sep="\t", encoding="cp949")  
G, node_index = create_ppi_network(network_data=network_data)  
entrez_list = list(node_index.keys())  

# 네트워크 활용 gene_phenotype 정보 생성
gene_phenotype_file = '/data/home/sss2061/식약처/gene_2023_phenotype_info.csv'
if os.path.isfile(gene_phenotype_file): 
    gene_phenotype_df = pd.read_csv(gene_phenotype_file, encoding='UTF-8', converters={'Phenotype': ast.literal_eval}) 
else: 
    gene_phenotype_info = {}
    for g in range(len(entrez_list)):
        conn_cur.execute(f"with tmp1 as (select g.geneid from gene g where g.entrezid = '{entrez_list[g]}'),"
                         f"tmp2 as (select gp.phenid from gene_phenotype gp, tmp1 where gp.geneid = tmp1.geneid)"
                         f"select distinct p.name from phenotype p, tmp2 where p.phenid = tmp2.phenid;")
        # TASS DB 기반 gene-phenotype 정보 추출
        selected_phenotype = conn_cur.fetchall()
        phenotypes = []
        for i in range(len(selected_phenotype)):
             phenotypes.append(selected_phenotype[i][0]) 
        gene_phenotype_info[entrez_list[g]] = phenotypes
        print(f'{g + 1}/{len(entrez_list)}')
    gene_phenotype_mapping = [[entrez_list[i], gene_phenotype_info.get(entrez_list[i])] for i in range(len(entrez_list))]
    gene_phenotype_df = pd.DataFrame(data=gene_phenotype_mapping, columns=['Entrez ID', 'Phenotype'])
    gene_phenotype_df.to_csv(gene_phenotype_file, index=False, encoding='UTF-8')

phenotype_list = []
for phen_list in gene_phenotype_df['Phenotype']:
    for phen in phen_list:
        if phen not in phenotype_list:
            phenotype_list.append(phen)

# 결과 리스트 초기화
Compound_list=[]

Herb_list=['HE00020661','HE00034300'] #사용자가 입력하는 herb list
for herb in Herb_list:
    conn_cur.execute(f"select compid from herb_compound hc where hc.herbid ='{herb}'")
    herb_compound=conn_cur.fetchall()

# herb_compound에서 compid 값을 추출하여 결과 리스트에 추가
    for item in herb_compound:
        Compound_list.append(item[0])

Compound_list=set(Compound_list)
Compound_list=list(Compound_list)

global directed_target_gene_list
directed_target_gene_list=[]  #사용자가 입력한 compound의 direct target gene 개수가 들어있는 list

global indirected_target_gene_list_count
indirected_target_gene_list_count=[] #사용자가 입력한 compound의 indirect target gene 개수가 들어있는 list

rwr_mapping_entrez_list=[] #사용자가 입력한 compound 별 rwr mapping entrez가 들어있는 list

for c in range(len(Compound_list)):
    
    compoundid1=Compound_list[c]
    
    rwr_mapping_entrez=compound_target(compoundid1)
    rwr_mapping_entrez_list.append(rwr_mapping_entrez)

rwr_mapping_entrez2 = combine_lists(rwr_mapping_entrez_list) #rwr mapping 조화평균 추출

rwr_result = pd.DataFrame(data=rwr_mapping_entrez2, columns=['Entrez ID', 'RWR_score'])
rwr_result = pd.merge(rwr_result, gene_phenotype_df, how='outer')
rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[
    rwr_result['Phenotype'].isnull()].apply(lambda x: [])
rwr_result = rwr_result.sort_values(by='RWR_score', ascending=False)

# phenotype 별 RWR score를 계산하기 위한 딕셔너리 생성
phenotype_rwr_score_dict = {}
for phen in phenotype_list:
    phenotype_rwr_score_dict[phen] = 0    
    
# 각 phenotype 별 RWR score 확인
for i in range(len(rwr_result)):
    rwr_score = rwr_result['RWR_score'].iloc[i]
    if rwr_result['Phenotype'].iloc[i]:
        for phen in rwr_result['Phenotype'].iloc[i]:
            phenotype_rwr_score_dict[phen] += rwr_score

Phenotype_score_Phenotype=list(phenotype_rwr_score_dict.keys())
Phenotype_score_Score=list(phenotype_rwr_score_dict.values())

#network score. csv 파일로 저장
inferred_phenotype2 = pd.DataFrame(data=[pair for pair in zip(list(phenotype_rwr_score_dict.keys()),
                                                             list(phenotype_rwr_score_dict.values()))],
                                  columns=['Phenotype', 'Network_score'])
inferred_phenotype2 = inferred_phenotype2.sort_values(by='Network_score', ascending=False)
if not os.path.exists('herb 결과'):
    os.makedirs('herb 결과') 
inferred_phenotype2.to_csv('herb 결과/ex2_network_score_multi-herb.csv',index=False, encoding='UTF-8')
    
end = time.time()
sec = (end - start)
result = datetime.timedelta(seconds=sec)
print("걸린 시간 : ",result)
print(f"걸린 시간 : {end - start:.5f} sec")
# Out:
# /tmp/ipykernel_281138/192689118.py:234: DtypeWarning: Columns (1,2,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   network_data = pd.read_csv("/data/home/sss2061/식약처/Data/BIOGRID-ORGANISM-Homo_sapiens.tab3.txt", sep="\t", encoding="cp949")
# Number of created nodes: 27421
# Number of created edges: 817463
# Compound CP00456974 Target gene 개수 0
# Compound CP00456974 indirected_Target gene 개수 23
# RWR iteration = 1, Iteration until convergence ...
# 6.443250350615669 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.2086333912199796 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.19660631540694648 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.03834392272447799 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP04514556 Target gene 개수 0
# Compound CP04514556 indirected_Target gene 개수 98
# RWR iteration = 1, Iteration until convergence ...
# 24.439381011322304 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.66780135613287 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.9121011300437752 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.18198959305795112 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.036385696684116745 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP09804498 Target gene 개수 0
# Compound CP09804498 indirected_Target gene 개수 97
# RWR iteration = 1, Iteration until convergence ...
# 24.20021488712216 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.584839136981791 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.9020430870438391 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.1800535633238708 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.03600097780939047 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00446623 Target gene 개수 0
# Compound CP00446623 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP05101422 Target gene 개수 0
# Compound CP05101422 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP10524831 Target gene 개수 0
# Compound CP10524831 indirected_Target gene 개수 99
# RWR iteration = 1, Iteration until convergence ...
# 24.6799911943857 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.699371184799192 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.9218082530686034 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.18390236784664538 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.036770175177289616 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP04477916 Target gene 개수 0
# Compound CP04477916 indirected_Target gene 개수 21
# RWR iteration = 1, Iteration until convergence ...
# 5.963400334527653 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.106635271423053 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.1768800920414818 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.03456089649959971 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP04449839 Target gene 개수 9
# Compound CP04449839 indirected_Target gene 개수 246
# RWR iteration = 1, Iteration until convergence ...
# 61.551152181847954 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 12.024552336201106 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 2.3954810733064074 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.4788592996686163 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.09576844967161913 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP18420334 Target gene 개수 0
# Compound CP18420334 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP25631850 Target gene 개수 0
# Compound CP25631850 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00446458 Target gene 개수 0
# Compound CP00446458 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00000118 Target gene 개수 0
# Compound CP00000118 indirected_Target gene 개수 138
# RWR iteration = 1, Iteration until convergence ...
# 34.037346634062835 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 6.553155118214478 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.2954997143909526 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.25875102282543117 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.0517426253552009 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP05094567 Target gene 개수 0
# Compound CP05094567 indirected_Target gene 개수 2
# RWR iteration = 1, Iteration until convergence ...
# 1.404585286572893 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.2473150484390028 -> 0.027420999999999997
# RWR iteration = 3
# Converged
# Compound CP00446576 Target gene 개수 0
# Compound CP00446576 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP28981796 Target gene 개수 0
# Compound CP28981796 indirected_Target gene 개수 21
# RWR iteration = 1, Iteration until convergence ...
# 5.963400334527653 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.106635271423053 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.1768800920414818 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.03456089649959971 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP00448970 Target gene 개수 0
# Compound CP00448970 indirected_Target gene 개수 98
# RWR iteration = 1, Iteration until convergence ...
# 24.43944486691913 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.671097545513556 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.9118006882093919 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.18197408866602852 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.03638511753204982 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00009652 Target gene 개수 1
# Compound CP00009652 indirected_Target gene 개수 156
# RWR iteration = 1, Iteration until convergence ...
# 39.1572626957971 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 7.552603367973716 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.499813408296125 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.29967938788530757 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.05993092297543446 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00018996 Target gene 개수 1
# Compound CP00018996 indirected_Target gene 개수 241
# RWR iteration = 1, Iteration until convergence ...
# 59.55179976857136 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 11.620438847287895 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 2.3153047151912247 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.4628528970159558 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.09256755878118203 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP17463836 Target gene 개수 0
# Compound CP17463836 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00451780 Target gene 개수 0
# Compound CP00451780 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00493843 Target gene 개수 0
# Compound CP00493843 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP64876393 Target gene 개수 0
# Compound CP64876393 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP04519732 Target gene 개수 0
# Compound CP04519732 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP23975830 Target gene 개수 18
# Compound CP23975830 indirected_Target gene 개수 153
# RWR iteration = 1, Iteration until convergence ...
# 49.63603109485672 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 9.651508145391851 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.9189179919216448 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.38351333384363523 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.07669798249556005 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00006746 Target gene 개수 0
# Compound CP00006746 indirected_Target gene 개수 150
# RWR iteration = 1, Iteration until convergence ...
# 36.91634863816533 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 7.135002389069659 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.4108366708333833 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.28176717809079277 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.056347621529651074 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00446987 Target gene 개수 0
# Compound CP00446987 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP04481089 Target gene 개수 2
# Compound CP04481089 indirected_Target gene 개수 116
# RWR iteration = 1, Iteration until convergence ...
# 28.758459509746285 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.498502574246815 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.084424781896009 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.21653436410814372 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.043296641856296426 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP28514627 Target gene 개수 0
# Compound CP28514627 indirected_Target gene 개수 21
# RWR iteration = 1, Iteration until convergence ...
# 5.963400334527653 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.106635271423053 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.1768800920414818 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.03456089649959971 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP28983390 Target gene 개수 0
# Compound CP28983390 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP28981686 Target gene 개수 0
# Compound CP28981686 indirected_Target gene 개수 21
# RWR iteration = 1, Iteration until convergence ...
# 5.963400334527653 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.106635271423053 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.1768800920414818 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.03456089649959971 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP04515428 Target gene 개수 0
# Compound CP04515428 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP04519939 Target gene 개수 0
# Compound CP04519939 indirected_Target gene 개수 104
# RWR iteration = 1, Iteration until convergence ...
# 25.87952522798293 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.925274104372194 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.968879224186556 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.19344722960677208 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.03868318815521002 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00006748 Target gene 개수 0
# Compound CP00006748 indirected_Target gene 개수 174
# RWR iteration = 1, Iteration until convergence ...
# 42.67513516070532 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 8.26912942184026 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.6402702777102132 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.32778768198164643 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.0655537730138281 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP04481670 Target gene 개수 0
# Compound CP04481670 indirected_Target gene 개수 97
# RWR iteration = 1, Iteration until convergence ...
# 24.199459527334206 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.61409478611926 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.9027340666368049 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.18004521049237365 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.03600003219180033 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP28514687 Target gene 개수 0
# Compound CP28514687 indirected_Target gene 개수 21
# RWR iteration = 1, Iteration until convergence ...
# 5.963400334527653 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.106635271423053 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.1768800920414818 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.03456089649959971 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP00009909 Target gene 개수 0
# Compound CP00009909 indirected_Target gene 개수 115
# RWR iteration = 1, Iteration until convergence ...
# 28.518473645685262 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.464165180200316 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.074803120388584 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.21456685680989987 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.042907838353036395 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00000317 Target gene 개수 120
# Compound CP00000317 indirected_Target gene 개수 766
# RWR iteration = 1, Iteration until convergence ...
# 248.71987931736072 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 49.42448254673045 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 9.88249321426231 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 1.9763928058389817 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.3952769549273673 -> 0.027420999999999997
# RWR iteration = 6, Iteration until convergence ...
# 0.07905367066523106 -> 0.027420999999999997
# RWR iteration = 7
# Converged
# Compound CP00007427 Target gene 개수 0
# Compound CP00007427 indirected_Target gene 개수 121
# RWR iteration = 1, Iteration until convergence ...
# 29.95818265904036 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.753633391982464 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.132351471643021 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2261388386569154 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04521689273913164 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP08978232 Target gene 개수 2
# Compound CP08978232 indirected_Target gene 개수 114
# RWR iteration = 1, Iteration until convergence ...
# 28.27892071883107 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.406721801006601 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.065368538734103 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.21266216179044045 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04252564976133954 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00369889 Target gene 개수 0
# Compound CP00369889 indirected_Target gene 개수 108
# RWR iteration = 1, Iteration until convergence ...
# 26.839019880411218 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.119328350270361 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.007745261389545 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20114771788697963 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04022241988651032 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00000872 Target gene 개수 3
# Compound CP00000872 indirected_Target gene 개수 181
# RWR iteration = 1, Iteration until convergence ...
# 45.155558973321234 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 8.751369629256567 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.739729165451118 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.34768095131150767 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.0695309527477111 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP28981010 Target gene 개수 0
# Compound CP28981010 indirected_Target gene 개수 26
# RWR iteration = 1, Iteration until convergence ...
# 7.163040439197745 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.3584849014923914 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.22439779321455502 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.044070597285013294 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP04477881 Target gene 개수 0
# Compound CP04477881 indirected_Target gene 개수 21
# RWR iteration = 1, Iteration until convergence ...
# 5.963400334527653 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.106635271423053 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.1768800920414818 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.03456089649959971 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP28514753 Target gene 개수 0
# Compound CP28514753 indirected_Target gene 개수 21
# RWR iteration = 1, Iteration until convergence ...
# 5.963400334527653 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.106635271423053 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.1768800920414818 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.03456089649959971 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP00006468 Target gene 개수 2
# Compound CP00006468 indirected_Target gene 개수 280
# RWR iteration = 1, Iteration until convergence ...
# 68.90859963681554 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 13.50467069279193 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 2.6899835581811224 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.5377415950441419 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.1075443728013652 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00371578 Target gene 개수 7
# Compound CP00371578 indirected_Target gene 개수 528
# RWR iteration = 1, Iteration until convergence ...
# 128.41656319665685 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 25.38037733634436 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 5.070467379533606 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 1.0138621807857333 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.202770486127636 -> 0.027420999999999997
# RWR iteration = 6, Iteration until convergence ...
# 0.04055331272472576 -> 0.027420999999999997
# RWR iteration = 7
# Converged
# Compound CP09895088 Target gene 개수 0
# Compound CP09895088 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00014396 Target gene 개수 8
# Compound CP00014396 indirected_Target gene 개수 138
# RWR iteration = 1, Iteration until convergence ...
# 34.837544531281 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 6.707873363842651 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.327133896929036 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2651366402217572 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.05302053037216682 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP06311596 Target gene 개수 0
# Compound CP06311596 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP09917168 Target gene 개수 0
# Compound CP09917168 indirected_Target gene 개수 99
# RWR iteration = 1, Iteration until convergence ...
# 24.679278247752215 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.709758919005059 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.9214881306770997 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.18387986197986753 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.03676719503838843 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP23404293 Target gene 개수 0
# Compound CP23404293 indirected_Target gene 개수 11
# RWR iteration = 1, Iteration until convergence ...
# 3.564070492005361 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.6447368656355993 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.08206588167673562 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00446514 Target gene 개수 0
# Compound CP00446514 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00003043 Target gene 개수 0
# Compound CP00003043 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP04483652 Target gene 개수 0
# Compound CP04483652 indirected_Target gene 개수 98
# RWR iteration = 1, Iteration until convergence ...
# 24.440182054348686 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.641046145513374 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.9117518356896592 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.18193555447538184 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.0363806597726657 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP05483749 Target gene 개수 0
# Compound CP05483749 indirected_Target gene 개수 104
# RWR iteration = 1, Iteration until convergence ...
# 25.87929120867354 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.949512339441032 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.9695505033124011 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.19349639576982436 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.03868915701633869 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP04528905 Target gene 개수 0
# Compound CP04528905 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00369328 Target gene 개수 0
# Compound CP00369328 indirected_Target gene 개수 131
# RWR iteration = 1, Iteration until convergence ...
# 32.357465193603474 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 6.2351833255687295 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.228705335960288 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2453228829872221 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04905580478852409 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP49166020 Target gene 개수 0
# Compound CP49166020 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00369895 Target gene 개수 0
# Compound CP00369895 indirected_Target gene 개수 100
# RWR iteration = 1, Iteration until convergence ...
# 24.919301934938158 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.749443553624531 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.931253354440355 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.1858185172279866 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.03715337050126124 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00462924 Target gene 개수 0
# Compound CP00462924 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP05109265 Target gene 개수 0
# Compound CP05109265 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00369385 Target gene 개수 0
# Compound CP00369385 indirected_Target gene 개수 117
# RWR iteration = 1, Iteration until convergence ...
# 28.998287339488193 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.562053081471582 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0943857357167794 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.21841785361246224 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04367723583761863 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP18420259 Target gene 개수 0
# Compound CP18420259 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00454810 Target gene 개수 0
# Compound CP00454810 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00367103 Target gene 개수 0
# Compound CP00367103 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP04450550 Target gene 개수 2
# Compound CP04450550 indirected_Target gene 개수 160
# RWR iteration = 1, Iteration until convergence ...
# 39.315946053283625 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 7.6057048152181945 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.5061914844085849 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.30095741385532626 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.06018639145286279 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00028303 Target gene 개수 0
# Compound CP00028303 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00051824 Target gene 개수 0
# Compound CP00051824 indirected_Target gene 개수 128
# RWR iteration = 1, Iteration until convergence ...
# 31.63781785812657 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 6.078340431780156 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.199365389942388 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2395408395556943 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04790165645993127 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP05098674 Target gene 개수 0
# Compound CP05098674 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP50290710 Target gene 개수 0
# Compound CP50290710 indirected_Target gene 개수 19
# RWR iteration = 1, Iteration until convergence ...
# 5.483485411062498 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.0266210064594794 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.15972541882378147 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.030718702149698927 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP28988443 Target gene 개수 0
# Compound CP28988443 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00461159 Target gene 개수 0
# Compound CP00461159 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP09919394 Target gene 개수 0
# Compound CP09919394 indirected_Target gene 개수 97
# RWR iteration = 1, Iteration until convergence ...
# 24.1996015984098 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.601960173325171 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.9020106948030456 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.18005465456361686 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.036000927678129964 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00369870 Target gene 개수 0
# Compound CP00369870 indirected_Target gene 개수 99
# RWR iteration = 1, Iteration until convergence ...
# 24.679624165618325 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.700597042056403 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.9219373886721317 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.1839236616919964 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.03677196784473406 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP23975832 Target gene 개수 0
# Compound CP23975832 indirected_Target gene 개수 108
# RWR iteration = 1, Iteration until convergence ...
# 26.839037237442664 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.139534110456574 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0081835384891416 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2011856463572994 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04022636082248998 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP04451451 Target gene 개수 0
# Compound CP04451451 indirected_Target gene 개수 130
# RWR iteration = 1, Iteration until convergence ...
# 32.11782784925006 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 6.176653861973783 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.2187137558355823 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.24339798658229514 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04867087920099031 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00005126 Target gene 개수 19
# Compound CP00005126 indirected_Target gene 개수 521
# RWR iteration = 1, Iteration until convergence ...
# 127.53607108370706 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 25.200536050077677 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 5.034856675343799 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 1.0068268283529378 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.20136329827795615 -> 0.027420999999999997
# RWR iteration = 6, Iteration until convergence ...
# 0.04027186400092459 -> 0.027420999999999997
# RWR iteration = 7
# Converged
# Compound CP28983440 Target gene 개수 0
# Compound CP28983440 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP04478213 Target gene 개수 0
# Compound CP04478213 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00308895 Target gene 개수 8
# Compound CP00308895 indirected_Target gene 개수 195
# RWR iteration = 1, Iteration until convergence ...
# 50.91548702666736 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 9.896298229406352 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.9700901936720208 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.39374735059516053 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.07874551866814014 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP28514591 Target gene 개수 0
# Compound CP28514591 indirected_Target gene 개수 21
# RWR iteration = 1, Iteration until convergence ...
# 5.963400334527653 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.106635271423053 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.1768800920414818 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.03456089649959971 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP04483868 Target gene 개수 0
# Compound CP04483868 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP28988418 Target gene 개수 0
# Compound CP28988418 indirected_Target gene 개수 1
# RWR iteration = 1, Iteration until convergence ...
# 1.1646173940025948 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.20682717457901914 -> 0.027420999999999997
# RWR iteration = 3
# Converged
# Compound CP00497270 Target gene 개수 0
# Compound CP00497270 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP04478174 Target gene 개수 0
# Compound CP04478174 indirected_Target gene 개수 21
# RWR iteration = 1, Iteration until convergence ...
# 5.963400334527653 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.106635271423053 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.1768800920414818 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.03456089649959971 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP00453278 Target gene 개수 0
# Compound CP00453278 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP05095603 Target gene 개수 0
# Compound CP05095603 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00073765 Target gene 개수 0
# Compound CP00073765 indirected_Target gene 개수 97
# RWR iteration = 1, Iteration until convergence ...
# 24.19970859377732 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.607771296800288 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.9027637596570515 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.18008553627479587 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.036004166009950635 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP02573030 Target gene 개수 0
# Compound CP02573030 indirected_Target gene 개수 26
# RWR iteration = 1, Iteration until convergence ...
# 7.163040439197745 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.3584849014923914 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.22439779321455502 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.044070597285013294 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP00541040 Target gene 개수 0
# Compound CP00541040 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP07590488 Target gene 개수 0
# Compound CP07590488 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP28981708 Target gene 개수 0
# Compound CP28981708 indirected_Target gene 개수 21
# RWR iteration = 1, Iteration until convergence ...
# 5.963400334527653 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.106635271423053 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.1768800920414818 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.03456089649959971 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP00369317 Target gene 개수 8
# Compound CP00369317 indirected_Target gene 개수 223
# RWR iteration = 1, Iteration until convergence ...
# 56.03357126542107 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 10.92142229254721 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 2.1747389578389873 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.43470182391718026 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.08693681675830142 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP28983428 Target gene 개수 0
# Compound CP28983428 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00010198 Target gene 개수 0
# Compound CP00010198 indirected_Target gene 개수 146
# RWR iteration = 1, Iteration until convergence ...
# 35.956872142092806 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 6.93856423284001 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.3721161444991832 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.274082109581207 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.05481093501035508 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP07590779 Target gene 개수 0
# Compound CP07590779 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP05094705 Target gene 개수 0
# Compound CP05094705 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP07590846 Target gene 개수 0
# Compound CP07590846 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# ...
# Compound CP00057015 indirected_Target gene 개수 1
# RWR iteration = 1, Iteration until convergence ...
# 1.1646209306217155 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.2072093905523425 -> 0.027420999999999997
# RWR iteration = 3
# Converged
# Compound CP01336831 Target gene 개수 0
# Compound CP01336831 indirected_Target gene 개수 99
# RWR iteration = 1, Iteration until convergence ...
# 24.679519760096667 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.710501520671511 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.9218230230572807 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.1838966034650307 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.03676938769614625 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP18420246 Target gene 개수 0
# Compound CP18420246 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP04450699 Target gene 개수 4
# Compound CP04450699 indirected_Target gene 개수 112
# RWR iteration = 1, Iteration until convergence ...
# 29.399052767682598 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.6215786107213574 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1101164066792706 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.22163701974894875 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.044319106476113236 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP04524165 Target gene 개수 0
# Compound CP04524165 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP04528546 Target gene 개수 0
# Compound CP04528546 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00015515 Target gene 개수 0
# Compound CP00015515 indirected_Target gene 개수 139
# RWR iteration = 1, Iteration until convergence ...
# 34.277739119988794 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 6.593518654086759 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.304762788005759 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2606446304024096 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.052123611239477126 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP18420258 Target gene 개수 0
# Compound CP18420258 indirected_Target gene 개수 23
# RWR iteration = 1, Iteration until convergence ...
# 6.443250350615669 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.2086333912199796 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.19660631540694648 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.03834392272447799 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP45430097 Target gene 개수 0
# Compound CP45430097 indirected_Target gene 개수 98
# RWR iteration = 1, Iteration until convergence ...
# 24.439760827111126 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.647118548812157 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.9118448734620072 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.18197344303463928 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.03638497502205099 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00369348 Target gene 개수 0
# Compound CP00369348 indirected_Target gene 개수 101
# RWR iteration = 1, Iteration until convergence ...
# 25.159467376039874 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.789107655226805 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.9409255557749115 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.1877388019431549 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.03753738938579943 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP28981012 Target gene 개수 0
# Compound CP28981012 indirected_Target gene 개수 26
# RWR iteration = 1, Iteration until convergence ...
# 7.163040439197745 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.3584849014923914 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.22439779321455502 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.044070597285013294 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP28514709 Target gene 개수 0
# Compound CP28514709 indirected_Target gene 개수 21
# RWR iteration = 1, Iteration until convergence ...
# 5.963400334527653 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.106635271423053 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.1768800920414818 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.03456089649959971 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP04450557 Target gene 개수 0
# Compound CP04450557 indirected_Target gene 개수 174
# RWR iteration = 1, Iteration until convergence ...
# 42.675166846051106 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 8.27643667472972 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.6408444279262548 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.3278319743409201 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.0655620464176862 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00025724 Target gene 개수 0
# Compound CP00025724 indirected_Target gene 개수 212
# RWR iteration = 1, Iteration until convergence ...
# 51.793277075511256 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 10.086423367775463 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 2.0052455800485407 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.40076793734757177 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.08014983537628828 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP17463830 Target gene 개수 0
# Compound CP17463830 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP18420260 Target gene 개수 0
# Compound CP18420260 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP28981618 Target gene 개수 0
# Compound CP28981618 indirected_Target gene 개수 21
# RWR iteration = 1, Iteration until convergence ...
# 5.963400334527653 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.106635271423053 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.1768800920414818 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.03456089649959971 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP05101170 Target gene 개수 0
# Compound CP05101170 indirected_Target gene 개수 1
# RWR iteration = 1, Iteration until convergence ...
# 1.16464531568788 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.20104394696303712 -> 0.027420999999999997
# RWR iteration = 3
# Converged
# Compound CP00432627 Target gene 개수 0
# Compound CP00432627 indirected_Target gene 개수 99
# RWR iteration = 1, Iteration until convergence ...
# 24.679541006450137 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.698175531211583 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.9217124564692141 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.18388268923807138 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.03676783656956687 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00081892 Target gene 개수 2
# Compound CP00081892 indirected_Target gene 개수 129
# RWR iteration = 1, Iteration until convergence ...
# 31.877914209576982 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 6.131101093948064 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.2089428185721343 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.24145701034742695 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.048284566968140215 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00008698 Target gene 개수 0
# Compound CP00008698 indirected_Target gene 개수 113
# RWR iteration = 1, Iteration until convergence ...
# 28.038704777842234 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.358528854454802 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0558619774803453 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.21075605673953898 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04214303461984715 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00369893 Target gene 개수 0
# Compound CP00369893 indirected_Target gene 개수 95
# RWR iteration = 1, Iteration until convergence ...
# 23.719734969185765 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.530889099335615 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.8833399874368533 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.17622439332083048 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.03523423670216094 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00021590 Target gene 개수 0
# Compound CP00021590 indirected_Target gene 개수 4
# RWR iteration = 1, Iteration until convergence ...
# 1.884408086546634 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.3343720747211638 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.03653129291419326 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP21805423 Target gene 개수 0
# Compound CP21805423 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP04522298 Target gene 개수 0
# Compound CP04522298 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP00547732 Target gene 개수 0
# Compound CP00547732 indirected_Target gene 개수 153
# RWR iteration = 1, Iteration until convergence ...
# 37.63660188965106 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 7.266309458377702 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.4390836893470682 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.28752699482468846 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.05749942105679295 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP04450277 Target gene 개수 2
# Compound CP04450277 indirected_Target gene 개수 127
# RWR iteration = 1, Iteration until convergence ...
# 32.99811540918598 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 6.350093643601323 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.2537118630545336 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2504233959431939 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.05007687257300085 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00454896 Target gene 개수 0
# Compound CP00454896 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP28514649 Target gene 개수 0
# Compound CP28514649 indirected_Target gene 개수 21
# RWR iteration = 1, Iteration until convergence ...
# 5.963400334527653 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 1.106635271423053 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.1768800920414818 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.03456089649959971 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP08789184 Target gene 개수 0
# Compound CP08789184 indirected_Target gene 개수 98
# RWR iteration = 1, Iteration until convergence ...
# 24.43957469270032 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 4.667421271432778 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.9122710569889927 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.1819691340147283 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.03638465880349277 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP00068161 Target gene 개수 0
# Compound CP00068161 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# Compound CP09918186 Target gene 개수 0
# Compound CP09918186 indirected_Target gene 개수 0
# RWR iteration = 1, Iteration until convergence ...
# 0.9246826167726675 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 0.165431908121235 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.032586705274251636 -> 0.027420999999999997
# RWR iteration = 4
# Converged
# /tmp/ipykernel_281138/192689118.py:299: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[
# 걸린 시간 :  0:21:46.860768
# 걸린 시간 : 1306.86077 sec
