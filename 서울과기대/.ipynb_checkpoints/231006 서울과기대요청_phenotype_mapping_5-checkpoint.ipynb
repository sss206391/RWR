# %%
# rwr 조화평균 완료

import numpy as np
import pandas as pd
import configparser
import psycopg2
import os
import ast
import networkx as nx
import random
import time
import math
import datetime
import csv
import statistics
from collections import defaultdict
from statistics import harmonic_mean

start = time.time()

def calculate_mean(numbers):
    return sum(numbers) / len(numbers)

def calculate_standard_deviation(numbers):
    return statistics.stdev(numbers)

def combine_lists(full_list):
    combined = defaultdict(list)
    
    # 모든 리스트에 대한 처리
    for sublist in full_list:
        for item in sublist:
            entrez_id, rwr_score = item
            combined[entrez_id].append(rwr_score)
    
    # 조화평균 및 결과 리스트 만들기
    result = []
    for entrez_id, scores in combined.items():
        if len(scores) == 1:
            result.append([entrez_id, scores[0]])  # 값이 하나면 그대로 추가
        else:
            # 조화평균 계산
            harmonic_mean_score = harmonic_mean(scores)
            result.append([entrez_id, harmonic_mean_score])
    
    return result

def compound_target(compoundid):

    conn_cur.execute(f"with tmp1 as (select cg.geneid from compound_gene cg where (cg.compid = '{compoundid}' and cg.relationsign in ('activate','inhibit')))" 
                    f"select g.entrezid from gene g,tmp1 where g.geneid=tmp1.geneid;")
    compound_gene1=conn_cur.fetchall()

    compound_gene=set(compound_gene1)
    compound_gene=list(compound_gene)
    
    # Compound-target gene List 생성
    target_gene_list = [] 
    for i in range(len(compound_gene)):
        interaction_gene = compound_gene[i][0]
        if interaction_gene in entrez_list:
            target_gene_list.append(interaction_gene)        
        else:
            continue

    # restart node에 적용할 target gene List 생성
    target_node = [] 
    for entrez in target_gene_list:
        node_ = node_index.get(entrez) 
        target_node.append(node_)

    conn_cur.execute(f"with tmp2 as (select cg.geneid from compound_gene cg where cg.compid = '{compoundid}' and relationsign='associate')" 
                    f"select g.entrezid from gene g,tmp2 where g.geneid=tmp2.geneid;")

    compound_gene2=conn_cur.fetchall()

    compound_gene=set(compound_gene2)
    compound_gene=list(compound_gene)

    indirected_target_gene_list = [] 
    for i in range(len(compound_gene)):
        interaction_gene = compound_gene[i][0]
        if interaction_gene in entrez_list:
            indirected_target_gene_list.append(interaction_gene)        
        else:
            continue      

    num1=len(target_gene_list) #target gene list 갯수
    directed_target_gene_list.append(num1)
    num2=len(indirected_target_gene_list) #indirected target gene list 갯수 
    indirected_target_gene_list_count.append(num2)
    
    print("Compound",compoundid,"Target gene 개수",num1)
    print("Compound",compoundid,"indirected_Target gene 개수",num2)
    
    #indirect nodes 정의
    indirect_nodes= []
    for entrez in indirected_target_gene_list:
        node_ = node_index.get(entrez) 
        indirect_nodes.append(node_)

    # PPI network RWR을 위한 initialize
    initialized = RWR_initializing(G, seed_nodes=target_node,indirect_target_nodes=indirect_nodes, is_weighted=False) 

    # RWR 실행
    rwr = RWR(initialized=initialized, prob=0.2, max_iter=100, tol=1.0e-6)
    rwr_mapping_entrez = [[entrez_list[i], rwr[node_index.get(entrez_list[i])]] for i in range(len(entrez_list))]
    
    var_name1 = f'{compoundid}_num1'
    var_name2 = f'{compoundid}_num2'

    # 전역 변수 설정
    globals()[var_name1] = num1
    globals()[var_name2] = num2
    
    return rwr_mapping_entrez

def rwr_compound_target(count,entrez_list):
    
    num1=directed_target_gene_list[count]
    num2=indirected_target_gene_list_count[count]
    
    random_interaction_gene1 = random.sample(entrez_list, num1)
    remaining_entrez_list = [gene for gene in entrez_list if gene not in random_interaction_gene1]
    random_interaction_gene2 = random.sample(remaining_entrez_list, num2)
# restart node에 적용할 target gene List 생성
    target_node = [] 
    for entrez in random_interaction_gene1:
        node_ = node_index.get(entrez)
        target_node.append(node_)

    #indirect nodes 정의
    indirect_nodes= []
    for entrez in random_interaction_gene2:
        node_ = node_index.get(entrez)
        indirect_nodes.append(node_)

    # PPI network RWR을 위한 initialize
    initialized = RWR_initializing(G, seed_nodes=target_node,indirect_target_nodes=indirect_nodes, is_weighted=False) 
    
# RWR 실행
    rwr=RWR(initialized=initialized, prob=0.2, max_iter=100, tol=1.0e-6)
    rwr_mapping_entrez = [[entrez_list[i], rwr[node_index.get(entrez_list[i])]] for i in range(len(entrez_list))]
    return rwr_mapping_entrez

def create_ppi_network(network_data):
    network_data = network_data.astype({'Entrez Gene Interactor A': str,
                                        'Entrez Gene Interactor B': str})

    # symbol list를 생성하고 unique 값만 가지도록 생성
    symbolA = network_data.loc[:, 'Entrez Gene Interactor A'].to_list()
    symbolB = network_data.loc[:, 'Entrez Gene Interactor B'].to_list()

    symbol_list = symbolA + symbolB 
    symbol_list = set(symbol_list) 
    symbol_list = list(symbol_list)

    # 모든 symbol에 index를 딕셔너리에서 부여
    node_index = {}
    for i in range(len(symbol_list)):
        node_index[symbol_list[i]] = i

    # index로 node_list 생성
    node_list = node_index.values()

    # index로 edge_list 생성
    edge_list = network_data[['Entrez Gene Interactor A', 'Entrez Gene Interactor B']].values.tolist()  #
    for i in range(len(edge_list)):
        edge_list[i][0] = node_index.get(edge_list[i][0])
        edge_list[i][1] = node_index.get(edge_list[i][1])
    
    # 무방향 그래프 오브젝트 생성
    G = nx.Graph()

    # 그래프에 노드 추가
    G.add_nodes_from(node_list)

    # 그래프에 엣지 추가
    G.add_edges_from(edge_list)

    print(f'Number of created nodes: {G.number_of_nodes()}')
    print(f'Number of created edges: {G.number_of_edges()}')

    return G, node_index

def RWR_initializing(G, seed_nodes, indirect_target_nodes, is_weighted=False):
    norm_A = np.zeros(shape=(len(G), len(G)))
    if is_weighted:  
        for i, neighbor_dict in G.adjacency():
            for j, v in neighbor_dict.items():
                norm_A[i][j] = v.get("weight", 1 / len(neighbor_dict))
    else:  
        for i, neighbor_dict in G.adjacency():  
            for j, v in neighbor_dict.items():  
                norm_A[i][j] = 1 / len(neighbor_dict)
    
    # seed nodes와 indirect target nodes를 모두 포함한 딕셔너리 생성
    personalization = {node: 1 for node in seed_nodes}
    for node in indirect_target_nodes:
        personalization[node] = 0.3  
        
    r_0 = np.array([personalization.get(n, 0) for n in range(len(G))]) 
    r_c = np.repeat(1 / len(G), len(G)) 
    return {"norm_A": norm_A, "r_0": r_0, "r_c": r_c, "N": len(G)}

def RWR(initialized, prob=0.85, max_iter=100, tol=1.0e-6):
    if initialized is None:
        raise ValueError('initialized information must be required')

    norm_A = initialized['norm_A']  # 인접행렬 A (정규화된)
    r_0 = initialized['r_0']        # 시작 노드
    r_c = initialized['r_c']        # 가중치 행렬
    N = initialized['N']            # 노드의 개수
    for iteration in range(max_iter):
        r_prev = r_c
        r_c = prob * r_c @ norm_A + (1 - prob) * r_0  # RWR algorithm
        err = np.absolute(r_c - r_prev).sum()
        if err < N * tol:
            print(f'RWR iteration = {iteration + 1}')
            print('Converged')
            return r_c
        else:
            print(f'RWR iteration = {iteration + 1}, Iteration until convergence ...')
            print(f'{err} -> {N * tol}')
    return "NotConverged"

# postgresql DB 연동
config = configparser.ConfigParser()
config.read('db_config.ini')
conn=psycopg2.connect(host="168.131.30.66", dbname="coconut",user="dbuser",password="jnudl1") #데이터이름변경
conn_cur = conn.cursor()

# BIOGRID-Homo_sapiens Data 기반 PPI Network 구축
network_data = pd.read_csv("/data/home/sss2061/식약처/Data/BIOGRID-ORGANISM-Homo_sapiens.tab3.txt", sep="\t", encoding="cp949")  
G, node_index = create_ppi_network(network_data=network_data)  
entrez_list = list(node_index.keys())  

# 네트워크 활용 gene_phenotype 정보 생성
gene_phenotype_file = '/data/home/sss2061/식약처/gene_2023_phenotype_info.csv'
if os.path.isfile(gene_phenotype_file): 
    gene_phenotype_df = pd.read_csv(gene_phenotype_file, encoding='UTF-8', converters={'Phenotype': ast.literal_eval}) 
else: 
    gene_phenotype_info = {}
    for g in range(len(entrez_list)):
        conn_cur.execute(f"with tmp1 as (select g.geneid from gene g where g.entrezid = '{entrez_list[g]}'),"
                         f"tmp2 as (select gp.phenid from gene_phenotype gp, tmp1 where gp.geneid = tmp1.geneid)"
                         f"select distinct p.name from phenotype p, tmp2 where p.phenid = tmp2.phenid;")
        # TASS DB 기반 gene-phenotype 정보 추출
        selected_phenotype = conn_cur.fetchall()
        phenotypes = []
        for i in range(len(selected_phenotype)):
             phenotypes.append(selected_phenotype[i][0]) 
        gene_phenotype_info[entrez_list[g]] = phenotypes
        print(f'{g + 1}/{len(entrez_list)}')
    gene_phenotype_mapping = [[entrez_list[i], gene_phenotype_info.get(entrez_list[i])] for i in range(len(entrez_list))]
    gene_phenotype_df = pd.DataFrame(data=gene_phenotype_mapping, columns=['Entrez ID', 'Phenotype'])
    gene_phenotype_df.to_csv(gene_phenotype_file, index=False, encoding='UTF-8')

phenotype_list = []
for phen_list in gene_phenotype_df['Phenotype']:
    for phen in phen_list:
        if phen not in phenotype_list:
            phenotype_list.append(phen)

Compound_list=['CP00008477','CP04450546','CP05101890'] #사용자가 입력하는 compound list

global directed_target_gene_list
directed_target_gene_list=[]  #사용자가 입력한 compound의 direct target gene 개수가 들어있는 list

global indirected_target_gene_list_count
indirected_target_gene_list_count=[] #사용자가 입력한 compound의 indirect target gene 개수가 들어있는 list

rwr_mapping_entrez_list=[] #사용자가 입력한 compound 별 rwr mapping entrez가 들어있는 list

for c in range(len(Compound_list)):
    
    compoundid1=Compound_list[c]
    
    rwr_mapping_entrez=compound_target(compoundid1)
    rwr_mapping_entrez_list.append(rwr_mapping_entrez)

rwr_mapping_entrez2 = combine_lists(rwr_mapping_entrez_list) #rwr mapping 조화평균 추출

rwr_result = pd.DataFrame(data=rwr_mapping_entrez2, columns=['Entrez ID', 'RWR_score'])
rwr_result = pd.merge(rwr_result, gene_phenotype_df, how='outer')
rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[
    rwr_result['Phenotype'].isnull()].apply(lambda x: [])
rwr_result = rwr_result.sort_values(by='RWR_score', ascending=False)

# phenotype 별 RWR score를 계산하기 위한 딕셔너리 생성
phenotype_rwr_score_dict = {}
for phen in phenotype_list:
    phenotype_rwr_score_dict[phen] = 0    
    
# 각 phenotype 별 RWR score 확인
for i in range(len(rwr_result)):
    rwr_score = rwr_result['RWR_score'].iloc[i]
    if rwr_result['Phenotype'].iloc[i]:
        for phen in rwr_result['Phenotype'].iloc[i]:
            phenotype_rwr_score_dict[phen] += rwr_score

Phenotype_score_Phenotype=list(phenotype_rwr_score_dict.keys())
Phenotype_score_Score=list(phenotype_rwr_score_dict.values())

#network score. csv 파일로 저장
inferred_phenotype2 = pd.DataFrame(data=[pair for pair in zip(list(phenotype_rwr_score_dict.keys()),
                                                             list(phenotype_rwr_score_dict.values()))],
                                  columns=['Phenotype', 'Network_score'])
inferred_phenotype2 = inferred_phenotype2.sort_values(by='Network_score', ascending=False)

# if not os.path.exists('compound 결과'):
#     os.makedirs('compound 결과')
inferred_phenotype2.to_csv('5_network_score.csv',index=False, encoding='UTF-8')

#----------------------------------------------------------------1,000
output_dict={}
print("확인용 바깥",indirected_target_gene_list_count) #확인용
for h in range(1000):
    p_rwr_mapping_entrez_list=[] #1번당 compound별 random target gene rwr mapping list
    
    print(h,"번째 상황") # 제거
    for k in range(len(Compound_list)):
        rwr_mapping_entrez=rwr_compound_target(k,entrez_list)
        p_rwr_mapping_entrez_list.append(rwr_mapping_entrez)
    
    rwr_mapping_entrez3 = combine_lists(p_rwr_mapping_entrez_list) #rwr mapping 조화평균 추출
    
    rwr_result = pd.DataFrame(data=rwr_mapping_entrez3, columns=['Entrez ID', 'RWR_score'])
    rwr_result = pd.merge(rwr_result, gene_phenotype_df, how='outer')
    rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
    rwr_result = rwr_result.sort_values(by='RWR_score', ascending=False)
    
# phenotype 별 RWR score를 계산하기 위한 딕셔너리 생성
    phenotype_rwr_score_dict = {}
    for phen in phenotype_list:
        phenotype_rwr_score_dict[phen] = 0

# 각 phenotype 별 RWR score 확인
    for i in range(len(rwr_result)):
        rwr_score = rwr_result['RWR_score'].iloc[i]
        if rwr_result['Phenotype'].iloc[i]:
            for phen in rwr_result['Phenotype'].iloc[i]:
                phenotype_rwr_score_dict[phen] += rwr_score

    key_list=list(phenotype_rwr_score_dict.keys())
    for i in key_list:
        if i not in output_dict:
            output_dict[i]=list([phenotype_rwr_score_dict[i]])
        else:
            output_dict[i].append(phenotype_rwr_score_dict[i])
print("rwr 종료")

#rwr. score csv 파일로 저장
inferred_phenotype3 = pd.DataFrame(data=[pair for pair in zip(list(output_dict.keys()),
                                                             list(output_dict.values()))],
                                  columns=['Phenotype', 'Network_score'])
inferred_phenotype3 = inferred_phenotype3.sort_values(by='Network_score', ascending=False)

inferred_phenotype3.to_csv('5_P_value.csv',index=False, encoding='UTF-8')

P_value_Phenotype=list(output_dict.keys())
P_value_Score=list(output_dict.values())

#----------------------------------------------------------------z-score  
count=0
z_score_list=[]
outlier_list=[] #제거가능
P_value_list=[]
rank_number=0

for i in range(len(P_value_Score)):
    Numberlist=P_value_Score[i].copy()
    Numberlist.append(Phenotype_score_Score[i])

    # 평균 계산
    mean = calculate_mean(Numberlist)

    # 표준편차 계산
    std_deviation = calculate_standard_deviation(Numberlist)

    z_score=(Phenotype_score_Score[i]-mean)/std_deviation
    z_score_list.append(z_score)
    if z_score >=-2.58 and z_score<=2.58: #제거가능
        outlier=1
        count=count+1
    else:
        outlier=0 
    outlier_list.append(outlier) #제거가능

    Numberlist.sort(reverse=True)

    rank=Numberlist.index(Phenotype_score_Score[i]) #순위찾기
    if rank<5:
        rank_number=rank_number+1
    P_value_list.append(rank)


#------------------------------------
phenotype_umlsid = []
# phenotype_list를 순회하면서 각 이름에 대한 UMLS ID를 가져옴
for phen_name in Phenotype_score_Phenotype:
    # 이름에 단일 따옴표가 포함된 경우 이스케이프
    escaped_name = phen_name.replace("'", "''")
    
    conn_cur.execute(f"SELECT umlsid FROM phenotype WHERE name = '{escaped_name}'")
    umlsid_result = conn_cur.fetchone()
    
    # UMLS ID가 존재하면 리스트에 추가
    if umlsid_result:
        phenotype_umlsid.append(umlsid_result[0])
    else:
        # UMLS ID가 없는 경우에 대한 처리 (예: None 또는 다른 기본값)
        phenotype_umlsid.append(None)

# 결과를 DataFrame으로 만들어 저장
phenotype_umlsid_df = pd.DataFrame({'Name': Phenotype_score_Phenotype, 'UMLSID': phenotype_umlsid})
print(phenotype_umlsid_df)

#------------------------

#     Phenotype_score['Phenotype']=Phenotype_score_Phenotype
#     Phenotype_score['Network_score']=Phenotype_score_Score
#     Phenotype_score['z-score']=z_score_list
#     Phenotype_score['outlier']=outlier_list

#     # Compound ID에 해당하는 inferred phenotype.csv 생성
Phenotype_score = pd.DataFrame({
    'Phenotype': Phenotype_score_Phenotype,
    'Network_score': Phenotype_score_Score,
    'z-score': z_score_list,
    'P-value': P_value_list,
    'UMLSID': phenotype_umlsid
})

Phenotype_score=Phenotype_score.sort_values(by='P-value',ascending=True)

#     # Compound ID에 해당하는 inferred phenotype.csv 생성
# if not os.path.exists('compound 결과'):
#     os.makedirs('compound 결과')
Phenotype_score.to_csv('5_검증.csv',index=False, encoding='UTF-8')
    
end = time.time()
sec = (end - start)
result = datetime.timedelta(seconds=sec)
print("걸린 시간 : ",result)
print(f"걸린 시간 : {end - start:.5f} sec")
# Out:
# /tmp/ipykernel_284965/1944860390.py:234: DtypeWarning: Columns (1,2,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   network_data = pd.read_csv("/data/home/sss2061/식약처/Data/BIOGRID-ORGANISM-Homo_sapiens.tab3.txt", sep="\t", encoding="cp949")
# Number of created nodes: 27421
# Number of created edges: 817463
# Compound CP00008477 Target gene 개수 0
# Compound CP00008477 indirected_Target gene 개수 44
# RWR iteration = 1, Iteration until convergence ...
# 11.482176523031033 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1519834680630527 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3948619515910806 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07849485095096598 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# Compound CP04450546 Target gene 개수 0
# Compound CP04450546 indirected_Target gene 개수 109
# RWR iteration = 1, Iteration until convergence ...
# 27.079846331171034 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.163523234304229 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0172174646062127 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20302656604548006 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.040600553649973926 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# Compound CP05101890 Target gene 개수 1
# Compound CP05101890 indirected_Target gene 개수 122
# RWR iteration = 1, Iteration until convergence ...
# 30.198609662201292 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.789443641261739 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1420797760027304 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.22803878399521588 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04559920089171626 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:286: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[
# 확인용 바깥 [44, 109, 122]
# 0 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.48180133310899 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.165118188368248 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3935369051794471 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.0782523280212862 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077958725016558 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.199765140490051 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0163772884392284 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20288570453967358 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04057664412753001 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.99695752789871 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.979669415255479 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1722443601126842 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424389036226112 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.0468485470202664 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 1 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.482023877108883 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.146119485120308 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3941105003640861 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07828106982326404 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077797066205825 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.206784132784787 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.016412678311321 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20304392902264135 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.040604768513097314 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.997138406628032 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.970580941308413 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1720210109886304 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2342439292451905 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.0468485634692823 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 2 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481820769888486 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1711664913071727 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3943781209127174 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07824291198059531 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.07799196780737 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.197824148540601 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0151384948593736 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2028839461714222 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.040576569267879815 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.9969601272408 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.974919006547872 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.172105933838706 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2342438580226726 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04684854371487532 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 3 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481923993980413 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1506756506068045 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.39379051060597375 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07813911170824617 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.07774523058304 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.216376671777657 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0158087446257753 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20288427266609524 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04057657279213782 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.996945478421384 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.9731782997039575 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.172058964697543 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.234243587545985 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04684855223809064 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 4 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481840934894054 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1408191628810362 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3927850843777228 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07816295539637308 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077710533932738 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.2039592822498495 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0152656922978491 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20288384798240744 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04057655687161081 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.996978451010744 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.974065713285319 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.172134524556278 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424358081004557 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.046848511702650364 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 5 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481845037193878 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.15554662109191 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.39367280375806196 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07829681407917803 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077710764263728 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.221896403144541 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0162449443251647 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20304342237059453 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04060427285272464 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.996926665521492 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.988560302766978 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1731645022274693 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23430779122195616 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04685996149172324 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 6 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481978949958506 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1558759329550963 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3941357301677826 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07823093827589912 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077962639126746 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.195434195256623 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0157602893443414 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20288419410455905 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.040576572180671164 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.996925921685225 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.979364354808281 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1730388053222207 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23437455650129063 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04687155857834341 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 7 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.48188181329704 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1610639797509545 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.39360129234660074 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.0782492391194519 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077776188452013 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.216265287350614 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.016924060677372 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2030335909015723 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04060308338947868 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.99685549336544 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.968761494605968 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1719304216227349 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424397409827166 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.046848559579296074 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 8 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.48202867732428 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1218174851784513 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.39441396094136955 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.0783021356910647 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077887875023887 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.192544320395862 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0156710346621873 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20288398741395913 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04057655513141602 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.99714918911731 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.977753601055948 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1736774121734723 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23437760338821162 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04687184928868142 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 9 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481891106034029 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.157281202612968 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.39423334573452057 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07832574942853908 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.07776607787297 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.200855099222443 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.015123767281378 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20288402312084716 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04057657362922176 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.997043132680393 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.975606787565291 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1732283484263335 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424611829066092 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04684879940911361 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 10 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481972522386382 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1421232534245123 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.39333065917933924 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.0782566063913125 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077897175860222 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.189692989556162 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.015354370177759 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2028838147326677 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.040576559175770396 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.996503284294043 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 6.001247274586817 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.172693849337444 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424379784206595 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.046848549846853195 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 11 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.482002596364062 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1435825409322216 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.39363475237568113 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07815177712093091 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.0778027796487 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.19395028439212 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0154034424153222 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20288391792764177 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.040576554263722815 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.997026729477376 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.97682445198676 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.172925420720894 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23438727103878176 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.046873823105970915 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 12 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481883036120877 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.160058002377778 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3941704362792575 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07827210836367784 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.07768727089318 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.227689034383908 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0162165745234482 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20303672591318386 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04060363184825579 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.996847977265787 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.975581744488682 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.172216273718269 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424471953927584 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04684862996396327 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 13 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481798008271827 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1681600568407564 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.39471996689251726 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07824113040525207 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077770363068698 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.214858595706171 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0160505808347422 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20288393361263626 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04057654231887044 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.997075872564032 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.983610942663131 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.172804803783433 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23428166178583756 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04685529128453735 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 14 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.482119667743058 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1466991650061233 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3936965143438388 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.0782931743485234 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077861474547205 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.200983457106441 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0153761478942038 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20288405895324035 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04057655646308865 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.997096542759444 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.97888718091778 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1726719266908818 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23437129489070566 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04687189132148408 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 15 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481989093465796 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1544204757838643 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3942200750481646 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07824624395315202 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.07789768726412 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.205016944373422 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0152285687534433 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20288401630278918 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04057657578888854 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.997330008946445 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.965808120729095 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1721861797776352 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424332195096145 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04684852755222767 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 16 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481814515349757 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.170310443937554 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.39339105151052867 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07810590302641489 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077896345662683 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.195345326825949 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0156579712359801 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20288368859266007 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04057652733280699 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.99691728519471 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.985718776957351 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1721896672497842 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424377582924388 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.046848546281314796 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 17 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481816260776027 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1631467130261455 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.39307003910573735 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07810949346797935 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077652220561117 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.212133298146812 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0158483950990815 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20288405632735193 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.040576579049210984 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.99708776537745 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.968752796771262 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1721859024710144 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424388476190874 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04684854750860314 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 18 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481756484535836 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1677477872026714 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3937213914324848 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.0782459434376806 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.07800251198244 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.200369145826269 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0164237566707024 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20303413260214814 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.040603101104610455 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.997071909157874 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.968755005959703 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1718470657917306 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424372046270295 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.046848546136905554 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 19 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481954376746362 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1864946710247355 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3950021181327125 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07831107223205605 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077684662986083 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.203884564484551 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.016776804795777 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20303508815464527 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04060279905206163 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.996972914759027 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.981567572206813 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1719908537996313 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424363009259822 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04684852814859197 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 20 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.482065568276916 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1370085637310696 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.39394281421806054 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07827786348754216 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077982821485445 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.193520340411058 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0160562908430468 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20304093770496423 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04060419967044069 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.996802474913327 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.992914923164232 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1725412438144487 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424384642101176 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04684855366421421 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 21 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481982739496539 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1388284123769803 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3935192013750116 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07825313264662577 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.07758737876976 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.22304161624128 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0160895957147549 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20288398974126656 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04057656291690794 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.997075180399776 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.967385933434301 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.172811488976606 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23436978712059944 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04687085205901611 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 22 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481935183819806 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.151628369537465 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3937310229504692 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07812126371156289 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.07779838145154 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.207441240846625 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0156590570923 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2028841374090665 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.0405765704322421 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.99690299249236 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.966952634412299 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1722851262972702 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2342438785679202 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.0468485581081705 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 23 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481936908442751 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1487696131776612 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.39369978125251026 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07825390118448014 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077749115323535 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.206535339088079 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0153207164822073 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2028839431180068 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04057656984105282 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.99699357181211 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.974540747134738 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1725339794622747 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424355490200183 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04684854969996423 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 24 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481994963429532 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.147094779386687 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.39394894776156464 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07826035450619304 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077993839236168 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.1957803987127384 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0160164431148317 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20294704042321576 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04058790188071232 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.996551211180265 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.99952428058508 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.172502335943556 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424411622298158 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04684855211049599 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 915 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481983926854612 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.150543526411573 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3936261110140219 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07811879631098788 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077900117822807 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.200156073178364 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0162423373154275 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20302617353366992 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.040601646586954 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.996599415282056 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.98804290415111 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1723044585767441 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424363579309795 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04684854222899827 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 916 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481703087410704 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1743447071711435 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.39485534037889713 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.078316377748002 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.0777063418457 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.209553790194342 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0160383991249844 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20300933383586778 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04059865645760747 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.996984442640816 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.97657769178988 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1721451872038122 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424350699416907 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04684853066869776 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 917 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481835549592699 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.154996262012397 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3939204177600241 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.0782668162097822 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077821870888336 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.215353625975215 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0163410538251996 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20294919898949879 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.040588216728550126 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.997012458200103 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.9758979543753075 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1729720511100539 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2343980609382286 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04687557699024132 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 918 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481919981846238 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.159906389773495 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3937172086645206 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07818140063542511 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.07778712090031 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.200646161034232 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0158029187701798 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20288454785182486 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04057658095263106 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.996912486937592 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.984232050676291 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1738264062297388 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2343979675503596 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.046875096316762184 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 919 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.48199848719022 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.140838118922116 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.393523936870934 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07827751697004508 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.07800375958417 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.193349617817605 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0154404370716064 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20288371032871794 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04057656750172991 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.996867673738194 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.973053234049578 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1719261810736943 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424380478128737 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.046848537979895584 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 920 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.48182241809583 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1575408211768323 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.39451254700633326 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07825940205069981 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.07783135907909 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.205443564322839 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0155203365400447 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.202884861235962 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04057671020758224 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.997005777321903 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.964592803327793 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.172615060617894 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2343051718846295 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.0468594629376945 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 921 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481807472794443 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1588584171830583 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.39482610598414164 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07835315628892996 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077539707604164 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.221201783126746 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.015436690893921 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20288352442794713 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04057651474786026 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.996700370186403 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.999225669224743 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1726443941025595 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424550805600347 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04684880248716962 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 922 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.481998164979984 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1466000764254733 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3940194091055667 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07826234040876247 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077726690612526 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.208433059595383 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.016467858705922 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.2030424706845691 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04060453109597435 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 30.99670811074837 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.994236344532922 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.1720360866057236 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.23424358855833816 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.046848549904798156 -> 0.027420999999999997
# RWR iteration = 6
# Converged
# /tmp/ipykernel_284965/1944860390.py:330: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()] = rwr_result['Phenotype'].loc[rwr_result['Phenotype'].isnull()].apply(lambda x: [])
# 923 번째 상황
# RWR iteration = 1, Iteration until convergence ...
# 11.482027203234368 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 2.1440392104797024 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 0.3933136621491606 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.07825064862927417 -> 0.027420999999999997
# RWR iteration = 5
# Converged
# RWR iteration = 1, Iteration until convergence ...
# 27.077680402008383 -> 0.027420999999999997
# RWR iteration = 2, Iteration until convergence ...
# 5.213007098272476 -> 0.027420999999999997
# RWR iteration = 3, Iteration until convergence ...
# 1.0162341717840475 -> 0.027420999999999997
# RWR iteration = 4, Iteration until convergence ...
# 0.20303689077639597 -> 0.027420999999999997
# RWR iteration = 5, Iteration until convergence ...
# 0.04060350458686818 -> 0.027420999999999997
